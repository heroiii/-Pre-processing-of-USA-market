# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Market.csv')
df = pd.DataFrame(data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
filt = df['Index'] == 'NYA'
filt
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 112452    False
# 112453    False
# 112454    False
# 112455    False
# 112456    False
# Name: Index, Length: 112457, dtype: bool

# %%
df1 = df.loc[filt, :]
df1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df1.dtypes
# Out:
# Index         object
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df1.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13947.000000  13946.000000  13945.000000  13944.000000  13938.000000
# mean    4452.147406   4469.312526   4434.262223   4453.026486   4455.094446
# std     4074.835507   4094.956718   4052.815490   4075.483921   4075.456765
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      654.989990    655.150024    655.039978    655.122513    655.807525
# 50%     2631.909912   2632.280029   2631.909912   2632.015014   2633.015014
# 75%     7339.489990   7376.315063   7277.509766   7339.397583   7342.787598
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume
# count  1.394700e+04
# mean   1.215565e+09
# std    1.834155e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.681975e+09
# max    1.145623e+10

# %%
float_cols =['Open','High','Low','Close','Adj Close','Volume']
df1[float_cols] = df1[float_cols].round().astype('Int64')
df1.dtypes
# Out:
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# Index        object
# Date         object
# Open          Int64
# High          Int64
# Low           Int64
# Close         Int64
# Adj Close     Int64
# Volume        Int64
# dtype: object

# %%
df1
# Out:
#       Index        Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA  12/31/1965    529    529    529    529        529           0
# 1       NYA    1/3/1966    527    527    527    527        527           0
# 2       NYA    1/4/1966    528    528    528    528        528           0
# 3       NYA    1/5/1966    531    531    531    531        531           0
# 4       NYA    1/6/1966    532    532    532    532        532           0
# ...     ...         ...    ...    ...    ...    ...        ...         ...
# 13943   NYA   5/24/2021  16375  16509  16375  16465      16465  2947400000
# 13944   NYA   5/25/2021  16465  16526  16375  16390      16390  3420870000
# 13945   NYA   5/26/2021  16390  16466  16388  16452      16452  3674490000
# 13946   NYA   5/27/2021  16452  16546  16452  16532      16532  5201110000
# 13947   NYA   5/28/2021  16532  16589  16532  16556      16556  4199270000
#
# [13948 rows x 8 columns]

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1['Date']
# Out:
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       1965-12-31
# 1       1966-01-03
# 2       1966-01-04
# 3       1966-01-05
# 4       1966-01-06
#            ...
# 13943   2021-05-24
# 13944   2021-05-25
# 13945   2021-05-26
# 13946   2021-05-27
# 13947   2021-05-28
# Name: Date, Length: 13948, dtype: datetime64[ns]

# %%
df1.sort_values(by='Date' , inplace = True)

df1
# Out:
# c:\users\e_koliji\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# ...

# %%
df2 = df1.dropna(subset =['Date','Adj Close'] ,how = 'any')
df2
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390  3420870000
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452  3674490000
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532  5201110000
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556  4199270000
#
# [13938 rows x 8 columns]

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.plot(df2['Date'] , df2['Adj Close'])
plt.xlabel('Date' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df2['Date'] , df2['Adj Close'])
plt.xlabel('Date' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
df3 = df1.dropna(subset =['Open','Adj Close'] ,how = 'any')
df3
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390  3420870000
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452  3674490000
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532  5201110000
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556  4199270000
#
# [13938 rows x 8 columns]

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.plot(df3['Open'] , df3['Adj Close'])
plt.xlabel('Open' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df3['Open'] , df3['Adj Close'])
plt.xlabel('Open' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
df4 = df1.dropna(subset =['High','Adj Close'] ,how = 'any')
df4
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390  3420870000
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452  3674490000
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532  5201110000
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556  4199270000
#
# [13937 rows x 8 columns]

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.plot(df4['High'] , df4['Adj Close'])
plt.xlabel('High' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df4['High'] , df4['Adj Close'])
plt.xlabel('High' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
df5 = df1.dropna(subset =['Low','Adj Close'] ,how = 'any')
df5
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390  3420870000
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452  3674490000
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532  5201110000
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556  4199270000
#
# [13936 rows x 8 columns]

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df5['Low'] , df5['Adj Close'])
plt.xlabel('Low' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
df6 = df1.dropna(subset =['Close','Adj Close'] ,how = 'any')
df6
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390  3420870000
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452  3674490000
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532  5201110000
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556  4199270000
#
# [13935 rows x 8 columns]

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df6['Close'] , df6['Adj Close'])
plt.xlabel('Close' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
df7 = df1.dropna(subset =['Volume','Adj Close'] ,how = 'any')
df7
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close      Volume
# 0       NYA 1965-12-31    529    529    529    529        529           0
# 1       NYA 1966-01-03    527    527    527    527        527           0
# 2       NYA 1966-01-04    528    528    528    528        528           0
# 3       NYA 1966-01-05    531    531    531    531        531           0
# 4       NYA 1966-01-06    532    532    532    532        532           0
# ...     ...        ...    ...    ...    ...    ...        ...         ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465  2947400000
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390  3420870000
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452  3674490000
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532  5201110000
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556  4199270000
#
# [13938 rows x 8 columns]

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df7['Volume'] , df7['Adj Close'])
plt.xlabel('Volume' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
df1.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13947.000000  13946.000000  13945.000000  13944.000000  13938.000000
# mean    4452.144834   4469.313495   4434.260739   4453.026033   4455.093916
# std     4074.832916   4094.959937   4052.814928   4075.484621   4075.457549
# min      348.000000    348.000000    348.000000    348.000000    348.000000
# 25%      655.000000    655.000000    655.000000    655.000000    656.000000
# 50%     2632.000000   2632.000000   2632.000000   2632.000000   2633.000000
# 75%     7339.500000   7376.500000   7278.000000   7339.750000   7342.750000
# max    16590.000000  16686.000000  16532.000000  16590.000000  16590.000000
#
#              Volume
# count  1.394700e+04
# mean   1.215565e+09
# std    1.834155e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.681975e+09
# max    1.145623e+10

# %%
df8 = df1.drop('Volume' , axis = 1)
df8
# Out:
#       Index       Date   Open   High    Low  Close  Adj Close
# 0       NYA 1965-12-31    529    529    529    529        529
# 1       NYA 1966-01-03    527    527    527    527        527
# 2       NYA 1966-01-04    528    528    528    528        528
# 3       NYA 1966-01-05    531    531    531    531        531
# 4       NYA 1966-01-06    532    532    532    532        532
# ...     ...        ...    ...    ...    ...    ...        ...
# 13943   NYA 2021-05-24  16375  16509  16375  16465      16465
# 13944   NYA 2021-05-25  16465  16526  16375  16390      16390
# 13945   NYA 2021-05-26  16390  16466  16388  16452      16452
# 13946   NYA 2021-05-27  16452  16546  16452  16532      16532
# 13947   NYA 2021-05-28  16532  16589  16532  16556      16556
#
# [13948 rows x 7 columns]

# %%
# Date<1970 & Adj Close>7000
# open<2000 & Adj Close>7000 , Open<6000 & Adj Close<2000
# high<2000 & Adj Close>7000 , high>6000 & Adj Close<2000
# low<2000 & Adj Close>7000
# close<2000 & Adj Close>7000
# volume=0

# %%
df8.describe()
# Out:
#                Open          High           Low         Close     Adj Close
# count  13947.000000  13946.000000  13945.000000  13944.000000  13938.000000
# mean    4452.144834   4469.313495   4434.260739   4453.026033   4455.093916
# std     4074.832916   4094.959937   4052.814928   4075.484621   4075.457549
# min      348.000000    348.000000    348.000000    348.000000    348.000000
# 25%      655.000000    655.000000    655.000000    655.000000    656.000000
# 50%     2632.000000   2632.000000   2632.000000   2632.000000   2633.000000
# 75%     7339.500000   7376.500000   7278.000000   7339.750000   7342.750000
# max    16590.000000  16686.000000  16532.000000  16590.000000  16590.000000

# %%
df8.dropna(inplace = True)
df8.describe()
# Out:
#                Open          High           Low         Close     Adj Close
# count  13932.000000  13932.000000  13932.000000  13932.000000  13932.000000
# mean    4456.382142   4473.279859   4437.910996   4456.411570   4456.806273
# std     4074.977658   4095.103590   4052.942082   4075.605456   4075.499391
# min      348.000000    348.000000    348.000000    348.000000    348.000000
# 25%      656.000000    656.000000    656.000000    656.000000    656.000000
# 50%     2634.000000   2634.000000   2634.000000   2634.000000   2634.000000
# 75%     7348.500000   7384.250000   7281.250000   7346.500000   7346.500000
# max    16590.000000  16686.000000  16532.000000  16590.000000  16590.000000

# %%
df1.isnull().sum()
# Out:
# Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# Volume        1
# dtype: int64

# %%
df8.isnull().sum()
# Out:
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# dtype: int64

# %%
for i in range(len(df1.index)):
    print(('total NaN in row',i+1,':'),df1.iloc[i].isnull().sum())
# Out:
# ('total NaN in row', 1, ':') 0
# ('total NaN in row', 2, ':') 0
# ('total NaN in row', 3, ':') 0
# ('total NaN in row', 4, ':') 0
# ('total NaN in row', 5, ':') 0
# ('total NaN in row', 6, ':') 0
# ('total NaN in row', 7, ':') 0
# ('total NaN in row', 8, ':') 0
# ('total NaN in row', 9, ':') 0
# ('total NaN in row', 10, ':') 0
# ('total NaN in row', 11, ':') 0
# ('total NaN in row', 12, ':') 0
# ('total NaN in row', 13, ':') 0
# ('total NaN in row', 14, ':') 0
# ('total NaN in row', 15, ':') 0
# ('total NaN in row', 16, ':') 0
# ('total NaN in row', 17, ':') 0
# ('total NaN in row', 18, ':') 0
# ('total NaN in row', 19, ':') 0
# ('total NaN in row', 20, ':') 0
# ('total NaN in row', 21, ':') 0
# ('total NaN in row', 22, ':') 0
# ('total NaN in row', 23, ':') 0
# ('total NaN in row', 24, ':') 0
# ('total NaN in row', 25, ':') 0
# ('total NaN in row', 26, ':') 0
# ('total NaN in row', 27, ':') 0
# ('total NaN in row', 28, ':') 0
# ('total NaN in row', 29, ':') 0
# ...

# %%
# mv done
# noise

# %%
# Date<1970 & Adj Close>7000
# open<2000 & Adj Close>7000 , Open<6000 & Adj Close<2000
# high<2000 & Adj Close>7000 , high>6000 & Adj Close<2000
# low<2000 & Adj Close>7000
# close<2000 & Adj Close>7000
# volume=0

# %%
noise_Date = df8[(df8['Adj Close']>7000) & (df8['Date']<'1970-01-01')]
noise_Date
# Out:
# Empty DataFrame
# Columns: [Index, Date, Open, High, Low, Close, Adj Close]
# Index: []

# %%
noise_open1 = df8[(df8['Adj Close']>5000) & (df8['Open']<2000)]
noise_open1
# Out:
#     Index       Date  Open  High  Low  Close  Adj Close
# 831   NYA 1969-05-29   612   612  612    612       6111

# %%
noise_open2 = df8[(df8['Adj Close']<2000) & (df8['Open']>5000)]
noise_open2
# Out:
#     Index       Date  Open  High  Low  Close  Adj Close
# 852   NYA 1969-06-30  5722   572  572    572        572

# %%
df8.drop(index = [831 , 852], inplace = True)

# %%
noise_High1 = df8[(df8['Adj Close']>6000) & (df8['High']<2000)]
noise_High1
# Out:
# Empty DataFrame
# Columns: [Index, Date, Open, High, Low, Close, Adj Close]
# Index: []

# %%
noise_High2 = df8[(df8['Adj Close']<2000) & (df8['High']>6000)]
noise_High2
# Out:
#     Index       Date  Open  High  Low  Close  Adj Close
# 829   NYA 1969-05-27   612  6124  612    612        612
# 833   NYA 1969-06-03   607  6066  607    607        607

# %%
df8.drop(index = [829 , 833], inplace = True)

# %%
noise_Low = df8[(df8['Adj Close']>6000) & (df8['Low']<2000)]
noise_Low
# Out:
# Empty DataFrame
# Columns: [Index, Date, Open, High, Low, Close, Adj Close]
# Index: []

# %%
noise_close = df8[(df8['Adj Close']>6000) & (df8['Close']<2000)]
noise_close
# Out:
# Empty DataFrame
# Columns: [Index, Date, Open, High, Low, Close, Adj Close]
# Index: []

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df8['High'] , df8['Adj Close'])
plt.xlabel('High' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df8['Close'] , df8['Adj Close'])
plt.xlabel('Close' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df8['Low'] , df8['Adj Close'])
plt.xlabel('Low' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.scatter(df8['Open'] , df8['Adj Close'])
plt.xlabel('Open' , size = 10)
plt.ylabel('Adj Close' , size = 10)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6) , dpi = 80)
plt.title('plot of Date & Adj Close',)
plt.plot(df8['Date'] , df8['Adj Close'] )
plt.xlabel('Date' , size = 14 ,color = 'green')
plt.ylabel('Adj Close' , size = 14, color = 'green')
plt.grid( color = 'red' , linestyle = '--' , linewidth = 0.5)
plt.show()
